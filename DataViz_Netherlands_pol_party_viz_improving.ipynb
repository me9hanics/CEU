# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# The initial graph to improve step-by-step:
#
# <img src="https://pbs.twimg.com/media/EvgM8chXMA4v-Cp?format=jpg&name=large" width="50%" height="50%">

# %% [markdown]
# (also available in the [recording at 22:46](https://npo.nl/start/serie/nieuwsuur/seizoen-2021/nieuwsuur_2179/afspelen))

# %% [markdown]
# 2.

# %%
initial_data = np.array([0.13, 0.064, 0.21, 0.096, 0.112, 0.388])
parties = np.array(["gem. Ned.", "PvdA", "PvdD", "GL", "SP"," "])

#Barplot matplotlib
bars = plt.bar(parties, initial_data*100)
plt.title('"I would not get vaccinated against Corona"')
plt.ylabel(" ")
plt.xlabel("Parties")
#Coloring the bars: yellow, red, blue, green, red
plt.bar(parties, initial_data*100, color = ["yellow", "red", "blue", "green", "red", "white"])
#Make background black, text white
plt.style.use('dark_background')
#Turn off window frame
plt.box(False)
#Remove ticks
plt.yticks([])

for bar in bars:
    yval = bar.get_height()
    if bar == bars[0] or bar == bars[2]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(int(yval))+"%", ha='center', va='bottom')
    elif bar == bars[1]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval, 2)), ha='center', va='bottom')
    elif bar == bars[3] or bar == bars[4]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval, 2))+"%", ha='center', va='bottom')




plt.show()

# %% [markdown]
# 3. Remove the remaining 38.8% area's bar

# %%
initial_data = np.array([0.13, 0.064, 0.21, 0.096, 0.112,])
parties = np.array(["gem. Ned.", "PvdA", "PvdD", "GL", "SP",])

#Barplot matplotlib
bars = plt.bar(parties, initial_data*100)
plt.title('"I would not get vaccinated against Corona"', pad=20)
plt.ylabel(" ")
plt.xlabel("Parties")
#Coloring the bars: yellow, red, blue, green, red
plt.bar(parties, initial_data*100, color = ["yellow", "red", "blue", "green", "red", ])
#Make background black, text white
plt.style.use('dark_background')
#Turn off window frame
plt.box(False)
#Remove ticks
plt.yticks([])

for bar in bars:
    yval = bar.get_height()
    if bar == bars[0] or bar == bars[2]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(int(yval))+"%", ha='center', va='bottom')
    elif bar == bars[1]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval, 2)), ha='center', va='bottom')
    elif bar == bars[3] or bar == bars[4]:
        plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval, 2))+"%", ha='center', va='bottom')

plt.tight_layout()


plt.show()

# %% [markdown]
# 4. Fix labels

# %%
initial_data = np.array([0.13, 0.064, 0.21, 0.096, 0.112,])
parties = np.array(["gem. Ned.", "PvdA", "PvdD", "GL", "SP",])

#Barplot matplotlib
bars = plt.bar(parties, initial_data*100)
plt.title('"I would not get vaccinated against Corona"', pad=20)
plt.ylabel(" ")
plt.xlabel("Parties")
#Coloring the bars: yellow, red, blue, green, red
plt.bar(parties, initial_data*100, color = ["yellow", "red", "blue", "green", "red", ])
#Make background black, text white
plt.style.use('dark_background')
#Turn off window frame
plt.box(False)
#Remove ticks
plt.yticks([])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval,2))+"%", ha='center', va='bottom')

plt.tight_layout()


plt.show()

# %% [markdown]
# 5. Color change (to do)

# %%
initial_data = np.array([0.13, 0.064, 0.21, 0.096, 0.112,])
parties = np.array(["gem. Ned.", "PvdA", "PvdD", "GL", "SP",])
colors = ["yellow", "#bc0c11", "#005741", "#47b113", "#db2428"]

#Barplot matplotlib
bars = plt.bar(parties, initial_data*100, color = colors)
plt.title('"I would not get vaccinated against Corona"', pad=20)
plt.ylabel(" ")
plt.xlabel("Parties")

plt.style.use('dark_background')
#Turn off window frame
plt.box(False)
#Remove ticks
plt.yticks([])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval,2))+"%", ha='center', va='bottom')

plt.tight_layout()


plt.show()

# %% [markdown]
# 6. Add parties

# %%
initial_data = np.array([0.13, 0.064, 0.21, 0.096, 0.112, 0.05, 0.05, 0.05, 0.11, 0.31, 0.57])
parties = np.array(["gem. \nNed.", "PvdA", "PvdD", "GL", "SP", "D66", "VVD", "CDA", "CU", "PVV", "FVD"])
order = ["SP", "PvdD", "GL", "PvdA", "gem. \nNed.", "D66", "CU", "CDA", "VVD", "PVV", "FVD", ]
reorder_data = np.array([initial_data[parties == i][0] for i in order]); order = np.array(order)
colors = ["#db2428", "#005741", "#47b113", "#bc0c11", "yellow", "#3c824e", "#36a6d6", "#7ec25d", "#ff8241", "#008fb1", "#900001"]

fig, ax = plt.subplots()
print("Figure size in inches: ", fig.get_size_inches())

#Barplot matplotlib
bars = plt.bar(order, reorder_data*100, color = colors)
plt.title('"I would not get vaccinated against Corona"', pad=20)
plt.ylabel(" ")
plt.xlabel("Parties")
#Make background black, text white
plt.style.use('dark_background')
#Turn off window frame
plt.box(False)
#Remove ticks
plt.yticks([])

# Set x-axis tick label size
ax.tick_params(axis='x', labelsize=8)  # Set labelsize to desired value


for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, str(round(yval,2))+"%", ha='center', va='bottom')

# Add x axis left-right arrow
ax.annotate("", xy=(0, -0.15), xytext=(1, -0.15), xycoords='axes fraction', 
             arrowprops=dict(arrowstyle="<->", color="white"), transform=ax.transAxes)

# Add x axis label
fig.text(0.05, -0.13, "Left", ha='center', va='bottom', color="white", transform=ax.transAxes)
fig.text(0.95, -0.13, "Right", ha='center', va='bottom', color="white", transform=ax.transAxes)

plt.show()
# Out:
# Figure size in inches:  [6.4 4.8]

# %% [markdown]
# Best plot:

# %%
initial_data = np.array([0.064, 0.21, 0.096, 0.112, 0.05, 0.05, 0.05, 0.11, 0.31, 0.57])
parties = np.array([ "PvdA", "PvdD", "GL", "SP", "D66", "VVD", "CDA", "CU", "PVV", "FVD"])
order = ["SP", "PvdD", "GL", "PvdA", "D66", "CU", "CDA", "VVD", "PVV", "FVD", ]
colors = ["#db2428", "#005741", "#47b113", "#bc0c11", "#3c824e", "#36a6d6", "#7ec25d", "#ff8241", "#008fb1", "#900001"]
reorder_data = np.array([initial_data[parties == i][0] for i in order]); order = np.array(order)

fig, ax = plt.subplots(); print("Figure size in inches: ", fig.get_size_inches())
fig.patch.set_facecolor('none')

plt.yticks([10, 20, 30, 40, 50], ["10%", "20%", "30%", "40%", "50%"], color="white", fontsize=10.5, weight='bold')
#plt.grid(axis='y', linestyle='--', alpha=1, color='white', linewidth=1.2)
#Put -- line here: y=10 between x=-0.8 and x=0; between x=0.2 and x=1; between x=7.2 and x=8 and between x=8.2 and x=9
plt.plot([-0.4, 0.4], [10, 10], 'w--', alpha=1, linewidth=1.2)
plt.plot([0.6, 1.4], [10, 10], 'w--', alpha=1, linewidth=1.2)
plt.plot([7.6, 8.4], [10, 10], 'w--', alpha=1, linewidth=1.2)
plt.plot([8.6, 9.4], [10, 10], 'w--', alpha=1, linewidth=1.2)
#y=20
plt.plot([0.6, 1.4], [20, 20], 'w--', alpha=1, linewidth=1.2)
plt.plot([7.6, 8.4], [20, 20], 'w--', alpha=1, linewidth=1.2)
plt.plot([8.6, 9.4], [20, 20], 'w--', alpha=1, linewidth=1.2)
#y=30
plt.plot([7.6, 8.4], [30, 30], 'w--', alpha=1, linewidth=1.2)
plt.plot([8.6, 9.4], [30, 30], 'w--', alpha=1, linewidth=1.2)
#y=40
plt.plot([8.6, 9.4], [40, 40], 'w--', alpha=1, linewidth=1.2)
#y=50
plt.plot([8.6, 9.4], [50, 50], 'w--', alpha=1, linewidth=1.2)

#Barplot matplotlib
bars = plt.bar(order, reorder_data*100, color = colors)
plt.title('"I would not get vaccinated against Corona"', pad=20, color="white", fontsize=13, weight='bold')
plt.ylabel(" ")
plt.xlabel("Parties", color="white", fontsize=10.5, weight='bold')
plt.xticks(color="white", fontsize=10.5, weight='bold')

#Turn off window frame
plt.box(False)

# Set x-axis tick label size
ax.tick_params(axis='x', labelsize=8)  # Set labelsize to desired value
ts = []
for bar in bars:
    yval = bar.get_height(); yval_mod = yval

    t =plt.text(bar.get_x() + bar.get_width()/2, yval_mod , str(round(yval,2))+"%", ha='center', va='bottom', fontsize=9.5, weight='bold', color='white')
    ts.append(t)
    



# Add x axis left-right arrow
ax.annotate("", xy=(0, -0.13), xytext=(1, -0.13), xycoords='axes fraction', 
             arrowprops=dict(arrowstyle="<->", color="white"), transform=ax.transAxes)

# Add x axis label
fig.text(0.05, -0.105, "Left", ha='center', va='bottom', color="white", transform=ax.transAxes, fontsize=10.5, weight='bold')
fig.text(0.95, -0.105, "Right", ha='center', va='bottom', color="white", transform=ax.transAxes, fontsize=10.5, weight='bold')

plt.axhline(y=13, color='red', linewidth=1.3,  label="Gem. Ned.", alpha=0.8)
plt.text(-0.5, 13, 'National \navg. (13%)', color='red', va='bottom', ha='right', fontsize=9.5, weight='bold')

plt.show()
# Out:
# Figure size in inches:  [6.4 4.8]
# C:\Users\hanic\AppData\Local\Temp\ipykernel_36548\2493351038.py:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b--" (-> color='b'). The keyword argument will take precedence.
#   plt.plot([-0.4, 0.4], [10, 10], 'b--', alpha=1, linewidth=1.2, color='white')
# C:\Users\hanic\AppData\Local\Temp\ipykernel_36548\2493351038.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b--" (-> color='b'). The keyword argument will take precedence.
#   plt.plot([0.6, 1.4], [10, 10], 'b--', alpha=1, linewidth=1.2, color='white')
# C:\Users\hanic\AppData\Local\Temp\ipykernel_36548\2493351038.py:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b--" (-> color='b'). The keyword argument will take precedence.
#   plt.plot([7.6, 8.4], [10, 10], 'b--', alpha=1, linewidth=1.2, color='white')
# ...

# %%
bars[-1].get_x()
# Out:
# 8.6

# %%
bar.__dict__
# Out:
# {'_stale': False,
#  'stale_callback': <function matplotlib.artist._stale_axes_callback(self, val)>,
#  '_axes': <Axes: title={'center': '"I would not get vaccinated against Corona"'}, xlabel='Parties', ylabel=' '>,
#  'figure': <Figure size 640x480 with 1 Axes>,
#  '_transform': <matplotlib.transforms.CompositeGenericTransform at 0x1ede2225240>,
#  '_transformSet': True,
#  '_visible': True,
#  '_animated': False,
#  '_alpha': None,
#  'clipbox': <matplotlib.transforms.TransformedBbox at 0x1ede22f97e0>,
#  '_clippath': None,
#  '_clipon': True,
#  '_label': '_nolegend_',
#  '_picker': None,
#  '_rasterized': False,
#  '_agg_filter': None,
#  '_mouseover': False,
#  '_callbacks': <matplotlib.cbook.CallbackRegistry at 0x1ede22f9660>,
#  '_remove_method': <function list.remove(value, /)>,
#  '_url': None,
#  '_gid': None,
#  '_snap': None,
#  '_sketch': None,
#  '_path_effects': [],
#  '_sticky_edges': _XYPair(x=[], y=[0]),
#  '_in_layout': True,
# ...
